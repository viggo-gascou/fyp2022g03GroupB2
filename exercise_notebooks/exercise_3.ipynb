# %%
import regex as re
from nltk.util import bigrams
from nltk.lm.preprocessing import pad_both_ends 
from nltk.util import everygrams
from nltk.lm.preprocessing import flatten, padded_everygram_pipeline, padded_everygrams
from nltk.util import ngrams
from nltk.lm import NgramCounter, MLE
from nltk.lm import KneserNeyInterpolated

# %%
with open("../tweeteval/datasets/irony/train_text.txt", "r") as f:
    irony = f.read()
with open("../tweeteval/datasets/stance/climate/train_text.txt", "r") as f:
    stance_climate = f.read()
with open("../pattern.txt", "r") as f:
    pat = re.compile(f.read())
with open("news-commentary-v16.txt") as f:
    news = f.read()

# %%
climate_tokens = [re.findall(pat, line) for line in stance_climate.split("\n")]

irony_tokens = [re.findall(pat, line) for line in irony.split("\n")]

news_tokens = [re.findall(pat, line) for line in news.split("\n")[:5000]]

all_tokens = irony_tokens + news_tokens

# %%
news_valid = [re.findall(pat, line) for line in news.split("\n")[-5000:]]

# %%
def train_model(dataset, n):
    _, vocab = padded_everygram_pipeline(2, all_tokens)
    grams = list(flatten(ngrams(sentence, n) for sentence in dataset))
    print(f"Length of {n}-gram list: {len(grams)}")
    train, _ = padded_everygram_pipeline(2, dataset)
    lm = MLE(n)
    lm.fit(train, vocab)
    return lm

# %%
lm = train_model(news_tokens,1)
# Out:
# Length of 1-gram list: 101784

# %%
lm.generate(15, text_seed=["king"], random_seed=231)
# Out:
# ['the',
#  'world',
#  'should',
#  'run',
#  'the',
#  'presidency',
#  'with',
#  'better',
#  'returns',
#  'on',
#  'exports',
#  'this',
#  'for',
#  'three-quarters',
#  'of']

# %%
lm.score("I")
lm.logscore("king")
# Out:
# -inf

# %%
len(lm.vocab)
# Out:
# 20187

# %%
lm.generate(4, text_seed=["I","super"])
# Out:
# ['promote', 'cooperation', 'from', 'large-scale']

# %%
test = list(flatten(everygrams(sent, 2, 2) for sent in news_valid))

# %%
print(len(news_valid))
# Out:
# 5000

# %%
test_set = set()
for line in test:
    perp = lm.perplexity(line)
    test_set.add(perp)
print(test_set)
# Out:
# {19459.096693351745, 8837.301149106554, 16663.774853122435, 667.6200421159634, 7452.266666666661, 10658.186207622934, 1828.3527845473116, 9127.12538024249, inf, 7215.626172874162, 19760.806107039258, 817.6642226197633, 79043.22442815703, 24393.268642140174, 6986.5, 211.1199944663984, 14431.252345748324, 39521.612214078516, 8426.036035570185, 8702.372597415157}

# %%
def train_model_kne(dataset, n):
    _, vocab = padded_everygram_pipeline(2, all_tokens)
    grams = list(flatten(ngrams(sentence, n) for sentence in dataset))
    print(f"Length of {n}-gram list: {len(grams)}")
    train, _ = padded_everygram_pipeline(2, dataset)
    lm2 = KneserNeyInterpolated(n)
    lm2.fit(train, vocab)
    return lm2

# %%
lm3 = train_model_kne(news_tokens, 2)
# Out:
# Length of 2-gram list: 96905

# %%
lm3.perplexity(test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-451208a8020d> in <cell line: 1>()
# ----> 1 lm3.perplexity(test)
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/api.py in perplexity(self, text_ngrams)
#     171
#     172         """
# --> 173         return pow(2.0, self.entropy(text_ngrams))
#     174
#     175     def generate(self, num_words=1, text_seed=None, random_seed=None):
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/api.py in entropy(self, text_ngrams)
#     162         """
#     163         return -1 * _mean(
# --> 164             [self.logscore(ngram[-1], ngram[:-1]) for ngram in text_ngrams]
#     165         )
#     166
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/api.py in <listcomp>(.0)
#     162         """
#     163         return -1 * _mean(
# --> 164             [self.logscore(ngram[-1], ngram[:-1]) for ngram in text_ngrams]
#     165         )
#     166
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/api.py in logscore(self, word, context)
#     141
#     142         """
# --> 143         return log_base2(self.score(word, context))
#     144
#     145     def context_counts(self, context):
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/api.py in score(self, word, context)
#     115         method.
#     116         """
# --> 117         return self.unmasked_score(
#     118             self.vocab.lookup(word), self.vocab.lookup(context) if context else None
#     119         )
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/models.py in unmasked_score(self, word, context)
#     110         else:
#     111             alpha, gamma = self.estimator.alpha_gamma(word, context)
# --> 112         return alpha + gamma * self.unmasked_score(word, context[1:])
#     113
#     114
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/models.py in unmasked_score(self, word, context)
#     102         if not context:
#     103             # The base recursion case: no context, we only have a unigram.
# --> 104             return self.estimator.unigram_score(word)
#     105         if not self.counts[context]:
#     106             # It can also happen that we have no data for this context.
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/smoothing.py in unigram_score(self, word)
#      95
#      96     def unigram_score(self, word):
# ---> 97         word_continuation_count, total_count = self._continuation_counts(word)
#      98         return word_continuation_count / total_count
#      99
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/smoothing.py in _continuation_counts(self, word, context)
#     123         higher_order_ngrams_with_word_count, total = 0, 0
#     124         for counts in higher_order_ngrams_with_context:
# --> 125             higher_order_ngrams_with_word_count += int(counts[word] > 0)
#     126             total += _count_values_gt_zero(counts)
#     127         return higher_order_ngrams_with_word_count, total
#
# KeyboardInterrupt:

# %%
import math

# %%
test_data, _ = padded_everygram_pipeline(2, news_valid)

for i, test in enumerate(test_data):
    if not math.isinf(lm2.perplexity(test)):
        print("PP( line: {0}):{1}".format(i, lm2.perplexity(test)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4e2e89dbbd6b> in <cell line: 3>()
#       2
#       3 for i, test in enumerate(test_data):
# ----> 4     if not math.isinf(lm2.perplexity(test)):
#       5         print("PP( line: {0}):{1}".format(i, lm2.perplexity(test)))
#
# NameError: name 'math' is not defined

# %%
test_set = set()
for line in test:
    try:
        perp = lm2.perplexity(line)
        test_set.add(perp)
    except ZeroDivisionError:
        pass
print(test_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-1317ca90b066> in <cell line: 2>()
#       2 for line in test:
#       3     try:
# ----> 4         perp = lm2.perplexity(line)
#       5         test_set.add(perp)
#       6     except ZeroDivisionError:
#
# NameError: name 'lm2' is not defined

# %%
test_set
# Out:
# set()

# %%
ngrams_linewise = list(list(everygrams(sent, 2, 2)) for sent in news_valid)
len(ngrams_linewise)
# Out:
# 5000

# %%
from tqdm import tqdm
lm = train_model_kne(irony_tokens, 2)
perplexity_list = []
for line in tqdm(ngrams_linewise):
    try:
        perplexity_list.append(print(lm.perplexity(line)))
    except ZeroDivisionError:
        perplexity_list.append("inf")
# Out:
# Length of 2-gram list: 36082
#   0%|          | 1/5000 [00:00<1:15:56,  1.10it/s]inf
#   1%|          | 55/5000 [00:27<28:44,  2.87it/s]inf
#   1%|          | 56/5000 [00:27<36:40,  2.25it/s]inf
#   1%|          | 57/5000 [00:28<35:52,  2.30it/s]inf
#   1%|          | 58/5000 [00:28<39:15,  2.10it/s]inf
# inf
#   1%|          | 60/5000 [00:29<37:04,  2.22it/s]inf
#   1%|          | 61/5000 [00:30<35:55,  2.29it/s]inf
#   1%|▏         | 63/5000 [00:31<35:28,  2.32it/s]inf
# inf
#   1%|▏         | 63/5000 [00:31<41:40,  1.97it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-b8a3660ea93f> in <cell line: 4>()
#       4 for line in tqdm(ngrams_linewise):
#       5     try:
# ----> 6         perplexity_list.append(print(lm.perplexity(line)))
#       7     except ZeroDivisionError:
#       8         perplexity_list.append("inf")
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/api.py in perplexity(self, text_ngrams)
#     171
#     172         """
# --> 173         return pow(2.0, self.entropy(text_ngrams))
#     174
#     175     def generate(self, num_words=1, text_seed=None, random_seed=None):
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/api.py in entropy(self, text_ngrams)
#     162         """
#     163         return -1 * _mean(
# --> 164             [self.logscore(ngram[-1], ngram[:-1]) for ngram in text_ngrams]
#     165         )
#     166
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/api.py in <listcomp>(.0)
#     162         """
#     163         return -1 * _mean(
# --> 164             [self.logscore(ngram[-1], ngram[:-1]) for ngram in text_ngrams]
#     165         )
#     166
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/api.py in logscore(self, word, context)
#     141
#     142         """
# --> 143         return log_base2(self.score(word, context))
#     144
#     145     def context_counts(self, context):
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/api.py in score(self, word, context)
#     115         method.
#     116         """
# --> 117         return self.unmasked_score(
#     118             self.vocab.lookup(word), self.vocab.lookup(context) if context else None
#     119         )
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/models.py in unmasked_score(self, word, context)
#     110         else:
#     111             alpha, gamma = self.estimator.alpha_gamma(word, context)
# --> 112         return alpha + gamma * self.unmasked_score(word, context[1:])
#     113
#     114
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/models.py in unmasked_score(self, word, context)
#     102         if not context:
#     103             # The base recursion case: no context, we only have a unigram.
# --> 104             return self.estimator.unigram_score(word)
#     105         if not self.counts[context]:
#     106             # It can also happen that we have no data for this context.
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/smoothing.py in unigram_score(self, word)
#      95
#      96     def unigram_score(self, word):
# ---> 97         word_continuation_count, total_count = self._continuation_counts(word)
#      98         return word_continuation_count / total_count
#      99
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/smoothing.py in _continuation_counts(self, word, context)
#     124         for counts in higher_order_ngrams_with_context:
#     125             higher_order_ngrams_with_word_count += int(counts[word] > 0)
# --> 126             total += _count_values_gt_zero(counts)
#     127         return higher_order_ngrams_with_word_count, total
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/smoothing.py in _count_values_gt_zero(distribution)
#      29     )
#      30     # We explicitly check that values are > 0 to guard against negative counts.
# ---> 31     return sum(
#      32         1 for dist_or_count in distribution.values() if as_count(dist_or_count) > 0
#      33     )
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/lm/smoothing.py in <genexpr>(.0)
#      29     )
#      30     # We explicitly check that values are > 0 to guard against negative counts.
# ---> 31     return sum(
#      32         1 for dist_or_count in distribution.values() if as_count(dist_or_count) > 0
#      33     )
#
# KeyboardInterrupt:

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e4cdc3a5-dd4a-4d72-a71a-972cea883107' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
